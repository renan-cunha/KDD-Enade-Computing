# %%
import pandas as pd
import numpy as np
from sys import path
from src import util
from src.process2014_2017 import ProcessEnade2014_2017
from src.process2011 import ProcessEnade2011
from src.process2008 import ProcessEnade2008
from src.process2005 import ProcessEnade2005
from src import config
from src import subject_manipulation
from typing import Tuple, List
from src.config import SUBJECT_DF_PATH, BLANK_LABEL, DELETION_LABEL, CANCELLED_LABEL, DIFFICULTIES, \
    MATH_SUBJECTS, COMPUTING_SUBJECTS, HUMAN_SUBJECTS, TECHNOLOGY_SUBJECTS
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import matplotlib.patches as mpatches

# %%
subject_df = subject_manipulation.get_processed_subject_df(SUBJECT_DF_PATH)

# %%
def get_dict_all_years(filter_by_ufpa: bool) -> dict:
    enade_2017 = ProcessEnade2014_2017(2017).get_data(filter_by_ufpa)
    enade_2014 = ProcessEnade2014_2017(2014).get_data(filter_by_ufpa)
    enade_2011 = ProcessEnade2011().get_data(filter_by_ufpa)
    enade_2008 = ProcessEnade2008().get_data(filter_by_ufpa)
    enade_2005 = ProcessEnade2005().get_data(filter_by_ufpa)
    return {2017: enade_2017, 
            2014: enade_2014, 
            2011: enade_2011,
            2008: enade_2008,
            2005: enade_2005}

# %%
dfs = get_dict_all_years(filter_by_ufpa=True)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (1,5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (49,55,58,68) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (67,68,69,70,71,72,73,74,76,77,78,79,80,81,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
def remove_absent_students(dfs):
    for x in dfs.keys():
        df = dfs[x]
        util.map_presence(df)
        dfs[x] = util.filter_present_students(df)
    return dfs

dfs = remove_absent_students(dfs)

# %%
def get_display_df(year: int, input_df: pd.DataFrame,
                   subject_df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    temp_subject_df = subject_df.loc[subject_df['ano'] == year].copy()
    
    subjects = util.get_subjects(temp_subject_df)
    input_df = util.add_all_score_categories(input_df, temp_subject_df, True, 
                                           subjects, util.get_subject_valid_questions)
    
    num_questions = []
    mean_acertos_by_subject = []
    std_acertos_by_subject = []
    column_zero_subject = []
    column_geq_one_subject = []
    column_all_subject = []
    num_alunos = input_df.shape[0]

    for subject in subjects:
        subject_questions = util.get_subject_valid_questions(subject, 
                                                                 temp_subject_df,
                                                                 input_df,
                                                                 just_objective=True)
        num_obj_subject_questions = len(subject_questions)
    
    
    
        mean_acertos_subject = input_df[f"ACERTOS_OBJ_{subject}"].mean()
    
        std_acertos_subject = input_df[f"ACERTOS_OBJ_{subject}"].std()
    
        zero_subject_percentage = list(input_df[f"ACERTOS_OBJ_{subject}"]).count(0) * 100 / num_alunos
    
        geq_one_subject_percentage = list(input_df[f"ACERTOS_OBJ_{subject}"] >= 1).count(True) * 100 / num_alunos
        
        all_subject_percentage = list(input_df[f"ACERTOS_OBJ_{subject}"] == num_obj_subject_questions).count(True) * 100 / num_alunos
        
        if num_obj_subject_questions > 0:
            num_questions.append(num_obj_subject_questions)
            mean_acertos_by_subject.append(mean_acertos_subject)
            std_acertos_by_subject.append(std_acertos_subject)
            column_zero_subject.append(zero_subject_percentage)
            column_geq_one_subject.append(geq_one_subject_percentage)
            column_all_subject.append(all_subject_percentage)
        else:
            num_questions.append(0)
            mean_acertos_by_subject.append(None)
            std_acertos_by_subject.append(None)
            column_zero_subject.append(None)
            column_geq_one_subject.append(None)
            column_all_subject.append(None)

    subjects_labels = [f"SCORE_OBJ_{x}" for x in subjects]

    mean_by_subject = input_df[subjects_labels].mean().values

    data = np.array([mean_by_subject, num_questions]).T

    display_df = pd.DataFrame(data=data, index=subjects, 
                          columns=["Nota %", "Nº Questões"])
    display_df["Nº Questões"] = display_df["Nº Questões"].astype(int, errors="ignore")
    display_df["Média Acertos"] = mean_acertos_by_subject
    display_df["Desvio Padrão Acertos"] = std_acertos_by_subject
    display_df["% de Zeros"] = column_zero_subject

    display_df["% de Alunos que acertaram pelo menos uma questão"] = column_geq_one_subject
    display_df["% de Alunos que acertaram todas"] = column_all_subject


    display_df = display_df.sort_values(by=["Nota %"]).round(2)

    
    return display_df, input_df

# %%
def make_display_dfs(dfs):
    display_dfs = {}
    for year in dfs.keys():
        enade_df = dfs[year]
        display_df, df = get_display_df(year, enade_df, subject_df)
        dfs[year] = df
        display_dfs[year] = display_df
    return display_dfs, dfs

display_dfs, dfs = make_display_dfs(dfs)

# %%
def bar_graph_display_df(df):
    ax = plt.subplot(111)
    ax.barh(df.index, df["Nota %"], color="gray")
    ax.grid(axis = 'x', color ='white', linestyle='-')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.title("Percentual de Acerto por Tema no ENADE")
    plt.xlabel("%")
    plt.xlim(0, 100)
    plt.show()
    
def make_radar_plot(series, title):
    values = list(series.values)
    labels = list(series.index)


# Number of variables we're plotting.
    num_vars = len(labels)


# Split the circle into even parts and save the angles
# so we know where to put each axis.
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The plot is a circle, so we need to "complete the loop"
# and append the start value to the end.
    values += values[:1]
    angles += angles[:1]

# ax = plt.subplot(polar=True)
    fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Draw the outline of our data.
    ax.plot(angles, values, color='#1aaf6c', linewidth=1)
# Fill it in.
    ax.fill(angles, values, color='#1aaf6c', alpha=0.25)

# Fix axis to go in the right order and start at 12 o'clock.
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)

# Draw axis lines for each angle and label.

    ax.set_thetagrids(np.degrees(angles), labels)

# Go through labels and adjust alignment based on where
# it is in the circle.
    for label, angle in zip(ax.get_xticklabels(), angles):
        if angle in (0, np.pi):
            label.set_horizontalalignment('center')
        elif 0 < angle < np.pi:
              label.set_horizontalalignment('left')
        else:
              label.set_horizontalalignment('right')

# Ensure radar goes from 0 to 100.
    ax.set_ylim(0, 100)
# You can also set gridlines manually like this:
# ax.set_rgrids([20, 40, 60, 80, 100])

# Set position of y-labels (0-100) to be in the middle
# of the first two axes.
    ax.set_rlabel_position(180 / num_vars)

# Add some custom styling.
# Change the color of the tick labels.
    ax.tick_params(colors='#222222')
# Make the y-axis (0-100) labels smaller.
    ax.tick_params(axis='y', labelsize=8)
# Change the color of the circular gridlines.
    ax.grid(color='#AAAAAA')
# Change the color of the outermost gridline (the spine).
    ax.spines['polar'].set_color('#222222')
# Change the background color inside the circle itself.
    ax.set_facecolor('#FAFAFA')

# Lastly, give the chart a title and give it some
# padding above the "Acceleration" label.
    ax.set_title(title, y=1.08)
    plt.show()

# %%
def create_column_combined_subject(row: pd.Series, subjects: list) -> float:
    result = 0
    any_column_present = False
    for subject in subjects:
        column_name = f"ACERTOS_OBJ_{subject}"
        if column_name in row.index:
            result += row[column_name]
            any_column_present = True # at least one subject is present
    if any_column_present:
        return result
    else:
        return None

def get_num_questions_poscomp(display_df: pd.DataFrame, subjects: list) -> int:
    result = 0
    for subject in subjects:
        if subject in display_df.index:
            result += display_df.loc[subject, "Nº Questões"]
    return result
    
def return_poscomp_score(df_original: pd.DataFrame, display_df: pd.DataFrame):
    
    df = df_original.copy()
    
    # Add columns
    categories = [MATH_SUBJECTS, COMPUTING_SUBJECTS, TECHNOLOGY_SUBJECTS, HUMAN_SUBJECTS]
    labels = ["Matemática", "Fundamentos da Computação", "Tecnologias da Computação", 
              "Contexto Social e Profissional"]
    labels_with_questions = []
    for subjects, label in zip(categories, labels):
        df[label] = df.apply(create_column_combined_subject, args=(subjects,), axis=1)
        
        # get score by student
        num_questions_subjects = get_num_questions_poscomp(display_df, subjects) 
        if num_questions_subjects > 0:
            df[label] = (df[label] * 100) / num_questions_subjects
            labels_with_questions.append(label)
        
    # return means core
    return df[labels_with_questions].mean()

# %%
def display_data_by_subject(year: int, dfs, display_dfs) -> pd.DataFrame:
    print(f"ANO de {year}")
    display_dfs[year] = display_dfs[year].loc[display_dfs[year]["Nº Questões"] != 0]
    bar_graph_display_df(display_dfs[year])
    poscomp_score = return_poscomp_score(dfs[year], display_dfs[year])
    make_radar_plot(poscomp_score, "Percentual de Acerto por Área no ENADE")
    return display_dfs[year]

# %%
year = 2017
display_data_by_subject(year, dfs, display_dfs)
# Out:
# ANO de 2017
#                                                     Nota %  Nº Questões  \
# Teoria da computação                                 13.24            2
# Banco de dados                                       30.88            2
# Compiladores                                         32.35            1
# Algoritmos e estruturas de dados                     35.29            4
# Arquitetura de computadores e sistemas operacio...   35.29            3
# Computação gráfica e processamento de imagem         41.18            1
# Sistemas distribuídos                                41.18            2
# Teoria dos grafos                                    44.12            1
# Fundamentos e técnicas de programação                47.06            1
# Lógica e matemática discreta                         47.06            1
# Engenharia de software e interação homem-comput...   50.00            2
# Redes de computadores                                52.94            2
# Inteligência artificial e computacional              61.76            2
# Sistemas digitais                                    61.76            1
# Ética, computador e sociedade                        70.59            1
# Paradigmas de linguagens de programação              73.53            1
#
#                                                     Média Acertos  \
# Teoria da computação                                         0.26
# Banco de dados                                               0.62
# Compiladores                                                 0.32
# Algoritmos e estruturas de dados                             1.41
# Arquitetura de computadores e sistemas operacio...           1.06
# Computação gráfica e processamento de imagem                 0.41
# Sistemas distribuídos                                        0.82
# Teoria dos grafos                                            0.44
# Fundamentos e técnicas de programação                        0.47
# Lógica e matemática discreta                                 0.47
# Engenharia de software e interação homem-comput...           1.00
# Redes de computadores                                        1.06
# Inteligência artificial e computacional                      1.24
# Sistemas digitais                                            0.62
# Ética, computador e sociedade                                0.71
# Paradigmas de linguagens de programação                      0.74
#
#                                                     Desvio Padrão Acertos  \
# Teoria da computação                                                 0.45
# Banco de dados                                                       0.55
# Compiladores                                                         0.47
# Algoritmos e estruturas de dados                                     1.08
# Arquitetura de computadores e sistemas operacio...                   0.81
# Computação gráfica e processamento de imagem                         0.50
# Sistemas distribuídos                                                0.80
# Teoria dos grafos                                                    0.50
# Fundamentos e técnicas de programação                                0.51
# Lógica e matemática discreta                                         0.51
# Engenharia de software e interação homem-comput...                   0.65
# Redes de computadores                                                0.60
# Inteligência artificial e computacional                              0.61
# Sistemas digitais                                                    0.49
# Ética, computador e sociedade                                        0.46
# Paradigmas de linguagens de programação                              0.45
#
#                                                     % de Zeros  \
# Teoria da computação                                     73.53
# Banco de dados                                           41.18
# Compiladores                                             67.65
# Algoritmos e estruturas de dados                         23.53
# Arquitetura de computadores e sistemas operacio...       23.53
# Computação gráfica e processamento de imagem             58.82
# Sistemas distribuídos                                    41.18
# Teoria dos grafos                                        55.88
# Fundamentos e técnicas de programação                    52.94
# Lógica e matemática discreta                             52.94
# Engenharia de software e interação homem-comput...       20.59
# Redes de computadores                                    14.71
# Inteligência artificial e computacional                   8.82
# Sistemas digitais                                        38.24
# Ética, computador e sociedade                            29.41
# Paradigmas de linguagens de programação                  26.47
#
#                                                     % de Alunos que acertaram pelo menos uma questão  \
# Teoria da computação                                                                           26.47
# Banco de dados                                                                                 58.82
# Compiladores                                                                                   32.35
# Algoritmos e estruturas de dados                                                               76.47
# Arquitetura de computadores e sistemas operacio...                                             76.47
# Computação gráfica e processamento de imagem                                                   41.18
# Sistemas distribuídos                                                                          58.82
# Teoria dos grafos                                                                              44.12
# Fundamentos e técnicas de programação                                                          47.06
# Lógica e matemática discreta                                                                   47.06
# Engenharia de software e interação homem-comput...                                             79.41
# Redes de computadores                                                                          85.29
# Inteligência artificial e computacional                                                        91.18
# Sistemas digitais                                                                              61.76
# Ética, computador e sociedade                                                                  70.59
# Paradigmas de linguagens de programação                                                        73.53
#
#                                                     % de Alunos que acertaram todas
# Teoria da computação                                                           0.00
# Banco de dados                                                                 2.94
# Compiladores                                                                  32.35
# Algoritmos e estruturas de dados                                               2.94
# Arquitetura de computadores e sistemas operacio...                             5.88
# Computação gráfica e processamento de imagem                                  41.18
# Sistemas distribuídos                                                         23.53
# Teoria dos grafos                                                             44.12
# Fundamentos e técnicas de programação                                         47.06
# Lógica e matemática discreta                                                  47.06
# Engenharia de software e interação homem-comput...                            20.59
# Redes de computadores                                                         20.59
# Inteligência artificial e computacional                                       32.35
# Sistemas digitais                                                             61.76
# Ética, computador e sociedade                                                 70.59
# Paradigmas de linguagens de programação                                       73.53

# %%
year = 2014
display_data_by_subject(year, dfs, display_dfs)
# Out:
# ANO de 2014
#                                                     Nota %  Nº Questões  \
# Teoria dos grafos                                    14.29            2
# Computação gráfica e processamento de imagem         17.86            1
# Sistemas digitais                                    17.86            1
# Teoria da computação                                 23.81            3
# Paradigmas de linguagens de programação              32.14            1
# Lógica e matemática discreta                         34.29            5
# Algoritmos e estruturas de dados                     35.71            2
# Compiladores                                         35.71            2
# Fundamentos e técnicas de programação                42.86            1
# Arquitetura de computadores e sistemas operacio...   75.00            1
# Banco de dados                                       82.14            1
# Engenharia de software e interação homem-comput...   85.71            3
#
#                                                     Média Acertos  \
# Teoria dos grafos                                            0.29
# Computação gráfica e processamento de imagem                 0.18
# Sistemas digitais                                            0.18
# Teoria da computação                                         0.71
# Paradigmas de linguagens de programação                      0.32
# Lógica e matemática discreta                                 1.71
# Algoritmos e estruturas de dados                             0.71
# Compiladores                                                 0.71
# Fundamentos e técnicas de programação                        0.43
# Arquitetura de computadores e sistemas operacio...           0.75
# Banco de dados                                               0.82
# Engenharia de software e interação homem-comput...           2.57
#
#                                                     Desvio Padrão Acertos  \
# Teoria dos grafos                                                    0.53
# Computação gráfica e processamento de imagem                         0.39
# Sistemas digitais                                                    0.39
# Teoria da computação                                                 0.66
# Paradigmas de linguagens de programação                              0.48
# Lógica e matemática discreta                                         1.12
# Algoritmos e estruturas de dados                                     0.66
# Compiladores                                                         0.60
# Fundamentos e técnicas de programação                                0.50
# Arquitetura de computadores e sistemas operacio...                   0.44
# Banco de dados                                                       0.39
# Engenharia de software e interação homem-comput...                   0.57
#
#                                                     % de Zeros  \
# Teoria dos grafos                                        75.00
# Computação gráfica e processamento de imagem             82.14
# Sistemas digitais                                        82.14
# Teoria da computação                                     39.29
# Paradigmas de linguagens de programação                  67.86
# Lógica e matemática discreta                             14.29
# Algoritmos e estruturas de dados                         39.29
# Compiladores                                             35.71
# Fundamentos e técnicas de programação                    57.14
# Arquitetura de computadores e sistemas operacio...       25.00
# Banco de dados                                           17.86
# Engenharia de software e interação homem-comput...        0.00
#
#                                                     % de Alunos que acertaram pelo menos uma questão  \
# Teoria dos grafos                                                                              25.00
# Computação gráfica e processamento de imagem                                                   17.86
# Sistemas digitais                                                                              17.86
# Teoria da computação                                                                           60.71
# Paradigmas de linguagens de programação                                                        32.14
# Lógica e matemática discreta                                                                   85.71
# Algoritmos e estruturas de dados                                                               60.71
# Compiladores                                                                                   64.29
# Fundamentos e técnicas de programação                                                          42.86
# Arquitetura de computadores e sistemas operacio...                                             75.00
# Banco de dados                                                                                 82.14
# Engenharia de software e interação homem-comput...                                            100.00
#
#                                                     % de Alunos que acertaram todas
# Teoria dos grafos                                                              3.57
# Computação gráfica e processamento de imagem                                  17.86
# Sistemas digitais                                                             17.86
# Teoria da computação                                                           0.00
# Paradigmas de linguagens de programação                                       32.14
# Lógica e matemática discreta                                                   0.00
# Algoritmos e estruturas de dados                                              10.71
# Compiladores                                                                   7.14
# Fundamentos e técnicas de programação                                         42.86
# Arquitetura de computadores e sistemas operacio...                            75.00
# Banco de dados                                                                82.14
# Engenharia de software e interação homem-comput...                            60.71

# %%
year = 2011
display_data_by_subject(year, dfs, display_dfs)
# Out:
# ANO de 2011
#                                                     Nota %  Nº Questões  \
# Paradigmas de linguagens de programação              19.61            3
# Sistemas digitais                                    23.53            1
# Fundamentos e técnicas de programação                30.88            4
# Lógica e matemática discreta                         31.37            3
# Redes de computadores                                32.35            2
# Arquitetura de computadores e sistemas operacio...   35.29            2
# Teoria da computação                                 47.06            3
# Teoria dos grafos                                    47.06            1
# Algoritmos e estruturas de dados                     52.94            5
# Probabilidade e estatística                          58.82            1
# Compiladores                                         61.76            2
# Engenharia de software e interação homem-comput...   61.76            2
#
#                                                     Média Acertos  \
# Paradigmas de linguagens de programação                      0.59
# Sistemas digitais                                            0.24
# Fundamentos e técnicas de programação                        1.24
# Lógica e matemática discreta                                 0.94
# Redes de computadores                                        0.65
# Arquitetura de computadores e sistemas operacio...           0.71
# Teoria da computação                                         1.41
# Teoria dos grafos                                            0.47
# Algoritmos e estruturas de dados                             2.65
# Probabilidade e estatística                                  0.59
# Compiladores                                                 1.24
# Engenharia de software e interação homem-comput...           1.24
#
#                                                     Desvio Padrão Acertos  \
# Paradigmas de linguagens de programação                              0.62
# Sistemas digitais                                                    0.44
# Fundamentos e técnicas de programação                                0.83
# Lógica e matemática discreta                                         0.97
# Redes de computadores                                                0.70
# Arquitetura de computadores e sistemas operacio...                   0.47
# Teoria da computação                                                 0.87
# Teoria dos grafos                                                    0.51
# Algoritmos e estruturas de dados                                     1.00
# Probabilidade e estatística                                          0.51
# Compiladores                                                         0.56
# Engenharia de software e interação homem-comput...                   0.66
#
#                                                     % de Zeros  \
# Paradigmas de linguagens de programação                  47.06
# Sistemas digitais                                        76.47
# Fundamentos e técnicas de programação                    17.65
# Lógica e matemática discreta                             41.18
# Redes de computadores                                    47.06
# Arquitetura de computadores e sistemas operacio...       29.41
# Teoria da computação                                     11.76
# Teoria dos grafos                                        52.94
# Algoritmos e estruturas de dados                          0.00
# Probabilidade e estatística                              41.18
# Compiladores                                              5.88
# Engenharia de software e interação homem-comput...       11.76
#
#                                                     % de Alunos que acertaram pelo menos uma questão  \
# Paradigmas de linguagens de programação                                                        52.94
# Sistemas digitais                                                                              23.53
# Fundamentos e técnicas de programação                                                          82.35
# Lógica e matemática discreta                                                                   58.82
# Redes de computadores                                                                          52.94
# Arquitetura de computadores e sistemas operacio...                                             70.59
# Teoria da computação                                                                           88.24
# Teoria dos grafos                                                                              47.06
# Algoritmos e estruturas de dados                                                              100.00
# Probabilidade e estatística                                                                    58.82
# Compiladores                                                                                   94.12
# Engenharia de software e interação homem-comput...                                             88.24
#
#                                                     % de Alunos que acertaram todas
# Paradigmas de linguagens de programação                                        0.00
# Sistemas digitais                                                             23.53
# Fundamentos e técnicas de programação                                          0.00
# Lógica e matemática discreta                                                   5.88
# Redes de computadores                                                         11.76
# Arquitetura de computadores e sistemas operacio...                             0.00
# Teoria da computação                                                          11.76
# Teoria dos grafos                                                             47.06
# Algoritmos e estruturas de dados                                               0.00
# Probabilidade e estatística                                                   58.82
# Compiladores                                                                  29.41
# Engenharia de software e interação homem-comput...                            35.29

# %%
year = 2008
display_data_by_subject(year, dfs, display_dfs)
# Out:
# ANO de 2008
#                                                     Nota %  Nº Questões  \
# Banco de dados                                       19.44            2
# Probabilidade e estatística                          22.22            2
# Engenharia de software e interação homem-comput...   26.39            2
# Compiladores                                         28.70            3
# Algoritmos e estruturas de dados                     29.17            2
# Lógica e matemática discreta                         29.17            2
# Redes de computadores                                33.33            5
# Sistemas digitais                                    33.33            2
# Teoria da computação                                 33.33            2
# Fundamentos e técnicas de programação                36.11            1
# Inteligência artificial e computacional              36.11            2
# Computação gráfica e processamento de imagem         37.50            2
# Ética, computador e sociedade                        66.67            1
# Arquitetura de computadores e sistemas operacio...   69.44            2
#
#                                                     Média Acertos  \
# Banco de dados                                               0.39
# Probabilidade e estatística                                  0.44
# Engenharia de software e interação homem-comput...           0.53
# Compiladores                                                 0.86
# Algoritmos e estruturas de dados                             0.58
# Lógica e matemática discreta                                 0.58
# Redes de computadores                                        1.67
# Sistemas digitais                                            0.67
# Teoria da computação                                         0.67
# Fundamentos e técnicas de programação                        0.36
# Inteligência artificial e computacional                      0.72
# Computação gráfica e processamento de imagem                 0.75
# Ética, computador e sociedade                                0.67
# Arquitetura de computadores e sistemas operacio...           1.39
#
#                                                     Desvio Padrão Acertos  \
# Banco de dados                                                       0.64
# Probabilidade e estatística                                          0.56
# Engenharia de software e interação homem-comput...                   0.70
# Compiladores                                                         0.76
# Algoritmos e estruturas de dados                                     0.60
# Lógica e matemática discreta                                         0.60
# Redes de computadores                                                1.20
# Sistemas digitais                                                    0.48
# Teoria da computação                                                 0.68
# Fundamentos e técnicas de programação                                0.49
# Inteligência artificial e computacional                              0.78
# Computação gráfica e processamento de imagem                         0.60
# Ética, computador e sociedade                                        0.48
# Arquitetura de computadores e sistemas operacio...                   0.64
#
#                                                     % de Zeros  \
# Banco de dados                                           69.44
# Probabilidade e estatística                              58.33
# Engenharia de software e interação homem-comput...       58.33
# Compiladores                                             36.11
# Algoritmos e estruturas de dados                         47.22
# Lógica e matemática discreta                             47.22
# Redes de computadores                                    13.89
# Sistemas digitais                                        33.33
# Teoria da computação                                     44.44
# Fundamentos e técnicas de programação                    63.89
# Inteligência artificial e computacional                  47.22
# Computação gráfica e processamento de imagem             33.33
# Ética, computador e sociedade                            33.33
# Arquitetura de computadores e sistemas operacio...        8.33
#
#                                                     % de Alunos que acertaram pelo menos uma questão  \
# Banco de dados                                                                                 30.56
# Probabilidade e estatística                                                                    41.67
# Engenharia de software e interação homem-comput...                                             41.67
# Compiladores                                                                                   63.89
# Algoritmos e estruturas de dados                                                               52.78
# Lógica e matemática discreta                                                                   52.78
# Redes de computadores                                                                          86.11
# Sistemas digitais                                                                              66.67
# Teoria da computação                                                                           55.56
# Fundamentos e técnicas de programação                                                          36.11
# Inteligência artificial e computacional                                                        52.78
# Computação gráfica e processamento de imagem                                                   66.67
# Ética, computador e sociedade                                                                  66.67
# Arquitetura de computadores e sistemas operacio...                                             91.67
#
#                                                     % de Alunos que acertaram todas
# Banco de dados                                                                 8.33
# Probabilidade e estatística                                                    2.78
# Engenharia de software e interação homem-comput...                            11.11
# Compiladores                                                                   0.00
# Algoritmos e estruturas de dados                                               5.56
# Lógica e matemática discreta                                                   5.56
# Redes de computadores                                                          0.00
# Sistemas digitais                                                              0.00
# Teoria da computação                                                          11.11
# Fundamentos e técnicas de programação                                         36.11
# Inteligência artificial e computacional                                       19.44
# Computação gráfica e processamento de imagem                                   8.33
# Ética, computador e sociedade                                                 66.67
# Arquitetura de computadores e sistemas operacio...                            47.22

# %%
year = 2005
display_data_by_subject(year, dfs, display_dfs)
# Out:
# ANO de 2005
#                                                     Nota %  Nº Questões  \
# Sistemas digitais                                    13.33            1
# Teoria da computação                                 16.67            2
# Algoritmos e estruturas de dados                     17.78            3
# Fundamentos e técnicas de programação                22.22            3
# Paradigmas de linguagens de programação              23.33            1
# Computação gráfica e processamento de imagem         25.00            2
# Compiladores                                         26.67            1
# Lógica e matemática discreta                         28.89            3
# Redes de computadores                                30.00            2
# Teoria dos grafos                                    30.00            1
# Inteligência artificial e computacional              33.33            1
# Arquitetura de computadores e sistemas operacio...   37.78            3
# Engenharia de software e interação homem-comput...   40.00            2
# Banco de dados                                       43.33            1
# Ética, computador e sociedade                        60.00            2
#
#                                                     Média Acertos  \
# Sistemas digitais                                            0.13
# Teoria da computação                                         0.33
# Algoritmos e estruturas de dados                             0.53
# Fundamentos e técnicas de programação                        0.67
# Paradigmas de linguagens de programação                      0.23
# Computação gráfica e processamento de imagem                 0.50
# Compiladores                                                 0.27
# Lógica e matemática discreta                                 0.87
# Redes de computadores                                        0.60
# Teoria dos grafos                                            0.30
# Inteligência artificial e computacional                      0.33
# Arquitetura de computadores e sistemas operacio...           1.13
# Engenharia de software e interação homem-comput...           0.80
# Banco de dados                                               0.43
# Ética, computador e sociedade                                1.20
#
#                                                     Desvio Padrão Acertos  \
# Sistemas digitais                                                    0.35
# Teoria da computação                                                 0.48
# Algoritmos e estruturas de dados                                     0.63
# Fundamentos e técnicas de programação                                0.76
# Paradigmas de linguagens de programação                              0.43
# Computação gráfica e processamento de imagem                         0.57
# Compiladores                                                         0.45
# Lógica e matemática discreta                                         0.68
# Redes de computadores                                                0.67
# Teoria dos grafos                                                    0.47
# Inteligência artificial e computacional                              0.48
# Arquitetura de computadores e sistemas operacio...                   0.90
# Engenharia de software e interação homem-comput...                   0.61
# Banco de dados                                                       0.50
# Ética, computador e sociedade                                        0.71
#
#                                                     % de Zeros  \
# Sistemas digitais                                        86.67
# Teoria da computação                                     66.67
# Algoritmos e estruturas de dados                         53.33
# Fundamentos e técnicas de programação                    50.00
# Paradigmas de linguagens de programação                  76.67
# Computação gráfica e processamento de imagem             53.33
# Compiladores                                             73.33
# Lógica e matemática discreta                             30.00
# Redes de computadores                                    50.00
# Teoria dos grafos                                        70.00
# Inteligência artificial e computacional                  66.67
# Arquitetura de computadores e sistemas operacio...       26.67
# Engenharia de software e interação homem-comput...       30.00
# Banco de dados                                           56.67
# Ética, computador e sociedade                            16.67
#
#                                                     % de Alunos que acertaram pelo menos uma questão  \
# Sistemas digitais                                                                              13.33
# Teoria da computação                                                                           33.33
# Algoritmos e estruturas de dados                                                               46.67
# Fundamentos e técnicas de programação                                                          50.00
# Paradigmas de linguagens de programação                                                        23.33
# Computação gráfica e processamento de imagem                                                   46.67
# Compiladores                                                                                   26.67
# Lógica e matemática discreta                                                                   70.00
# Redes de computadores                                                                          50.00
# Teoria dos grafos                                                                              30.00
# Inteligência artificial e computacional                                                        33.33
# Arquitetura de computadores e sistemas operacio...                                             73.33
# Engenharia de software e interação homem-comput...                                             70.00
# Banco de dados                                                                                 43.33
# Ética, computador e sociedade                                                                  83.33
#
#                                                     % de Alunos que acertaram todas
# Sistemas digitais                                                             13.33
# Teoria da computação                                                           0.00
# Algoritmos e estruturas de dados                                               0.00
# Fundamentos e técnicas de programação                                          0.00
# Paradigmas de linguagens de programação                                       23.33
# Computação gráfica e processamento de imagem                                   3.33
# Compiladores                                                                  26.67
# Lógica e matemática discreta                                                   0.00
# Redes de computadores                                                         10.00
# Teoria dos grafos                                                             30.00
# Inteligência artificial e computacional                                       33.33
# Arquitetura de computadores e sistemas operacio...                             6.67
# Engenharia de software e interação homem-comput...                            10.00
# Banco de dados                                                                43.33
# Ética, computador e sociedade                                                 36.67

# %%
def display_all_years_nota(all_dfs: dict) -> pd.DataFrame:
    data = {"2005": all_dfs[2005]["Nota %"].copy(),
            "2008": all_dfs[2008]["Nota %"].copy(),
            "2011": all_dfs[2011]["Nota %"].copy(),
            "2014": all_dfs[2014]["Nota %"].copy(),
            "2017": all_dfs[2017]["Nota %"].copy()}
    return pd.DataFrame(data)

# %%
def first_sample(original_row, reverse=False):
    row = original_row.copy()
    if reverse:
        row = row.iloc[::-1]
        
    is_nan = row.isna()
    for index, value in enumerate(row.values):
        if not is_nan[index]:
            return value
    return ValueError("No value found")


def compute_gain(row, absolute) -> float:
    
    # in case we have only one sample
    if list(row.isna()).count(True) == 4:
        return None
    else:
        first_value = first_sample(row)
        last_value = first_sample(row, reverse=True)
        
        if absolute:
            gain = last_value - first_value
        else:
            gain = last_value * 100 / first_value - 100
        
        return gain
    

subject_score_by_year = display_all_years_nota(display_dfs)
absolute_gain = subject_score_by_year.apply(compute_gain, args=(True,), axis=1)
percentage_gain = subject_score_by_year.apply(compute_gain, args=(False,), axis=1)
subject_score_by_year["Ganho Absoluto"] = absolute_gain
subject_score_by_year["Ganho Percentual"] = percentage_gain
subject_score_by_year
# Out:
#                                                      2005   2008   2011  \
# Algoritmos e estruturas de dados                    17.78  29.17  52.94
# Arquitetura de computadores e sistemas operacio...  37.78  69.44  35.29
# Banco de dados                                      43.33  19.44    NaN
# Compiladores                                        26.67  28.70  61.76
# Computação gráfica e processamento de imagem        25.00  37.50    NaN
# Engenharia de software e interação homem-comput...  40.00  26.39  61.76
# Fundamentos e técnicas de programação               22.22  36.11  30.88
# Inteligência artificial e computacional             33.33  36.11    NaN
# Lógica e matemática discreta                        28.89  29.17  31.37
# Paradigmas de linguagens de programação             23.33    NaN  19.61
# Probabilidade e estatística                           NaN  22.22  58.82
# Redes de computadores                               30.00  33.33  32.35
# Sistemas digitais                                   13.33  33.33  23.53
# Sistemas distribuídos                                 NaN    NaN    NaN
# Teoria da computação                                16.67  33.33  47.06
# Teoria dos grafos                                   30.00    NaN  47.06
# Ética, computador e sociedade                       60.00  66.67    NaN
#
#                                                      2014   2017  \
# Algoritmos e estruturas de dados                    35.71  35.29
# Arquitetura de computadores e sistemas operacio...  75.00  35.29
# Banco de dados                                      82.14  30.88
# Compiladores                                        35.71  32.35
# Computação gráfica e processamento de imagem        17.86  41.18
# Engenharia de software e interação homem-comput...  85.71  50.00
# Fundamentos e técnicas de programação               42.86  47.06
# Inteligência artificial e computacional               NaN  61.76
# Lógica e matemática discreta                        34.29  47.06
# Paradigmas de linguagens de programação             32.14  73.53
# Probabilidade e estatística                           NaN    NaN
# Redes de computadores                                 NaN  52.94
# Sistemas digitais                                   17.86  61.76
# Sistemas distribuídos                                 NaN  41.18
# Teoria da computação                                23.81  13.24
# Teoria dos grafos                                   14.29  44.12
# Ética, computador e sociedade                         NaN  70.59
#
#                                                     Ganho Absoluto  \
# Algoritmos e estruturas de dados                             17.51
# Arquitetura de computadores e sistemas operacio...           -2.49
# Banco de dados                                              -12.45
# Compiladores                                                  5.68
# Computação gráfica e processamento de imagem                 16.18
# Engenharia de software e interação homem-comput...           10.00
# Fundamentos e técnicas de programação                        24.84
# Inteligência artificial e computacional                      28.43
# Lógica e matemática discreta                                 18.17
# Paradigmas de linguagens de programação                      50.20
# Probabilidade e estatística                                  36.60
# Redes de computadores                                        22.94
# Sistemas digitais                                            48.43
# Sistemas distribuídos                                          NaN
# Teoria da computação                                         -3.43
# Teoria dos grafos                                            14.12
# Ética, computador e sociedade                                10.59
#
#                                                     Ganho Percentual
# Algoritmos e estruturas de dados                           98.481440
# Arquitetura de computadores e sistemas operacio...         -6.590789
# Banco de dados                                            -28.732979
# Compiladores                                               21.297338
# Computação gráfica e processamento de imagem               64.720000
# Engenharia de software e interação homem-comput...         25.000000
# Fundamentos e técnicas de programação                     111.791179
# Inteligência artificial e computacional                    85.298530
# Lógica e matemática discreta                               62.893735
# Paradigmas de linguagens de programação                   215.173596
# Probabilidade e estatística                               164.716472
# Redes de computadores                                      76.466667
# Sistemas digitais                                         363.315829
# Sistemas distribuídos                                            NaN
# Teoria da computação                                      -20.575885
# Teoria dos grafos                                          47.066667
# Ética, computador e sociedade                              17.650000

# %%
"""Sistemas Distribuídos nao possui esse valor, omito do grafico ou nao?"""
def plot_bar_gain(column, title):
    ax = plt.subplot(111)
    subject_score_by_year_gain = subject_score_by_year[column].copy()
    subject_score_by_year_gain = subject_score_by_year_gain.sort_values()
    subject_score_by_year_gain = subject_score_by_year_gain.loc[subject_score_by_year_gain.index != "Sistemas distribuídos"]
    ax.barh(subject_score_by_year_gain.index, subject_score_by_year_gain, color="gray")
    ax.grid(axis = 'x', color ='white', linestyle='-')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.title(title)
    plt.show()

# %%
title = "Ganho Absoluto por Tema no ENADE (Nota do ultimo ano menos a do primeiro)"
plot_bar_gain("Ganho Absoluto", title)

# %%
title = "Ganho Percentual por Tema no ENADE ((ultimo ano * 100 / primeiro ano) - 100)"
plot_bar_gain("Ganho Percentual", title)

# %%
"""Numero de questões respondidas por categoria considerando todos os anos
    
    contador para cada categoria iniciado em 0
    para cada prova
        para cada categoria
            multiplicar numero de presentes pelo numero de questões da categoria
            incrementar o contador da categoria
     """

def return_num_answered(display_dfs, original_dfs, multiply_by_students=True):
    num_questions_answered_dfs = []
    for year in display_dfs.keys():
        df = display_dfs[year]
        num_questions = df["Nº Questões"].astype(int).copy()
        if multiply_by_students:
            num_questions *= original_dfs[year].shape[0]
        num_questions_answered_dfs.append(num_questions)
    num_questions_answered_df = pd.concat(num_questions_answered_dfs, axis=1)
    num_answered_by_category = num_questions_answered_df.fillna(0).sum(axis=1).sort_index()
    return num_answered_by_category

"""Numero de questões respondidas corretamente por categoria considerando todos os anos
    
    contador para cada categoria iniciado em 0
    para cada prova
        para cada categoria
            multiplicar numero de presentes pelo numero de questões acertadas da categoria
            incrementar o contador da categoria
     """

def return_num_correct(dfs, categories):
    columns = [f"ACERTOS_OBJ_{x}" for x in categories]
    correct_by_category  = pd.concat(dfs.values(), ignore_index=True)
    correct_by_category = correct_by_category[columns].sum(0).sort_index()
    return correct_by_category
    

def get_all_years_combined_df(display_dfs, dfs, categories):
    num_answered = return_num_answered(display_dfs, dfs)
    num_correct = return_num_correct(dfs, categories)
    num_correct.index = num_answered.index
    data_df = {"Questões Respondidas no total (Questões x Alunos)": num_answered,
               "Acertos no Total (Acertos x Alunos)": num_correct}
    score_df_category = pd.DataFrame(data_df)
    score_df_category["Nota %"] = score_df_category.iloc[:, 1]*100/score_df_category.iloc[:, 0]
    score_df_category.iloc[:, 0] =  score_df_category.iloc[:, 0].astype(int)
    score_df_category.iloc[:, 1] =  score_df_category.iloc[:, 1].astype(int)

    score_df_category["Nota %"] = score_df_category["Nota %"].round(2)
    
    return score_df_category.sort_values(by=["Nota %"])

# %%
all_years_combined_subject = get_all_years_combined_df(display_dfs, dfs, util.get_subjects(subject_df))
bar_graph_display_df(all_years_combined_subject)
#make_radar_plot(all_years_combined_subject["Nota %"], "")
#poscomp_score = return_poscomp_score(all_years_combined_subject, display_dfs[year])
#make_radar_plot(poscomp_score, "Percentual de Acerto por Área no ENADE")
all_years_combined_subject
# Out:
#                                                     Questões Respondidas no total (Questões x Alunos)  \
# Teoria da computação                                                                              335
# Teoria dos grafos                                                                                 137
# Probabilidade e estatística                                                                        89
# Computação gráfica e processamento de imagem                                                      194
# Fundamentos e técnicas de programação                                                             256
# Sistemas digitais                                                                                 181
# Lógica e matemática discreta                                                                      387
# Algoritmos e estruturas de dados                                                                  439
# Compiladores                                                                                      262
# Paradigmas de linguagens de programação                                                           143
# Banco de dados                                                                                    198
# Redes de computadores                                                                             342
# Sistemas distribuídos                                                                              68
# Inteligência artificial e computacional                                                           170
# Arquitetura de computadores e sistemas operacio...                                                326
# Engenharia de software e interação homem-comput...                                                318
# Ética, computador e sociedade                                                                     130
#
#                                                     Acertos no Total (Acertos x Alunos)  \
# Teoria da computação                                                                 87
# Teoria dos grafos                                                                    40
# Probabilidade e estatística                                                          26
# Computação gráfica e processamento de imagem                                         61
# Fundamentos e técnicas de programação                                                82
# Sistemas digitais                                                                    58
# Lógica e matemática discreta                                                        127
# Algoritmos e estruturas de dados                                                    150
# Compiladores                                                                         91
# Paradigmas de linguagens de programação                                              51
# Banco de dados                                                                       71
# Redes de computadores                                                               125
# Sistemas distribuídos                                                                28
# Inteligência artificial e computacional                                              78
# Arquitetura de computadores e sistemas operacio...                                  153
# Engenharia de software e interação homem-comput...                                  170
# Ética, computador e sociedade                                                        84
#
#                                                     Nota %
# Teoria da computação                                 25.97
# Teoria dos grafos                                    29.20
# Probabilidade e estatística                          29.21
# Computação gráfica e processamento de imagem         31.44
# Fundamentos e técnicas de programação                32.03
# Sistemas digitais                                    32.04
# Lógica e matemática discreta                         32.82
# Algoritmos e estruturas de dados                     34.17
# Compiladores                                         34.73
# Paradigmas de linguagens de programação              35.66
# Banco de dados                                       35.86
# Redes de computadores                                36.55
# Sistemas distribuídos                                41.18
# Inteligência artificial e computacional              45.88
# Arquitetura de computadores e sistemas operacio...   46.93
# Engenharia de software e interação homem-comput...   53.46
# Ética, computador e sociedade                        64.62

# %%
dfs_br = get_dict_all_years(filter_by_ufpa=False)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (1,5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (49,55,58,68) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (67,68,69,70,71,72,73,74,76,77,78,79,80,81,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
dfs_br = remove_absent_students(dfs_br)
display_dfs_br, dfs_br = make_display_dfs(dfs_br)

# %%
all_years_combined_subject_br = get_all_years_combined_df(display_dfs_br, dfs_br, 
                                                          util.get_subjects(subject_df))
bar_graph_display_df(all_years_combined_subject_br)
#all_years_combined_subject_br

# %%
def get_max_score(ufpa, br) -> Tuple[float, str]:
    if ufpa >= br:
        return ufpa, "UFPA", "black"
    else:
        return br, "BR", "gray"
    
def get_min_score(ufpa, br) -> Tuple[float, str]:
    if ufpa < br:
        return ufpa, "UFPA", "black"
    else:
        return br, "BR", "gray"

# %%
def bar_grouped_graph_display_df(df_ufpa, df_br, width=0.4):
    
    ax = plt.subplot(111)
    
    df_br = df_br.reindex_like(df_ufpa)
    if not df_ufpa.index.equals(df_br.index):
        raise ValueError("The indices of dataframes should be equal")
    
    
    ufpa_score_series = df_ufpa["Nota %"]
    br_score_series = df_br["Nota %"]
    
    merged_df = pd.DataFrame({"Nota % UFPA": ufpa_score_series,
                              "Nota % BR": br_score_series})
    
    merged_df["max"] = merged_df.max(axis=1)
    merged_df = merged_df.sort_values(by=["max"])
    labels = merged_df.index
    ufpa_score_series = merged_df["Nota % UFPA"]
    br_score_series = merged_df["Nota % BR"]

    x = np.arange(start=0, stop=len(labels), step=1)
    for i, score_ufpa, score_br in zip(x, ufpa_score_series, br_score_series):
        bigger_score, bigger_label, bigger_color = get_max_score(score_ufpa, score_br)
        smaller_score, smaller_label, smaller_color = get_min_score(score_ufpa, score_br)
        ax.barh(i + width, bigger_score, width, color=bigger_color)
        ax.barh(i, smaller_score, width, color=smaller_color)
    
    ax.grid(axis = 'x', color ='white', linestyle='-')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set(yticks=x + width, yticklabels=labels)#, ylim=[2*width - 1, len(df_ufpa)])
    black_patch = mpatches.Patch(color='gray', label='BR')
    gray_patch = mpatches.Patch(color='black', label='UFPA')
    plt.legend(handles=[gray_patch, black_patch])
    plt.title("Percentual de Acerto por Tema no ENADE")
    vals = ax.get_xticks()
    ax.set_xticklabels([f'{int(x)} %' for x in vals])
    #plt.xlabel("%")
    #plt.xlim(0, 100)
    plt.show()

# %%
bar_grouped_graph_display_df(all_years_combined_subject, all_years_combined_subject_br)

# %%
def bar_grouped_graph_display_df(df_ufpa, df_br, width=0.4):
    
    ax = plt.subplot(111)
    
    df_br = df_br.reindex_like(df_ufpa)
        
    ufpa_score_series = df_ufpa["Nota %"]
    br_score_series = df_br["Nota %"]
    
    merged_df = pd.DataFrame({"Nota % UFPA": ufpa_score_series,
                              "Nota % BR": br_score_series})
    
    merged_df = merged_df.sort_index(ascending=False)
    
    labels = merged_df.index
    ufpa_score_series = merged_df["Nota % UFPA"]
    br_score_series = merged_df["Nota % BR"]

    x = np.arange(start=0, stop=len(labels), step=1)
    ax.barh(x + width, ufpa_score_series, width, color="black", label="UFPA")
    ax.barh(x, br_score_series, width, color="gray", label = "BR")
    
    ax.grid(axis = 'x', color ='white', linestyle='-')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set(yticks=x + width, yticklabels=labels)#, ylim=[2*width - 1, len(df_ufpa)])
    plt.legend()
    plt.title("Percentual de Acerto por Tema no ENADE")
    vals = ax.get_xticks()
    ax.set_xticklabels([f'{int(x)} %' for x in vals])
    #plt.xlabel("%")
    #plt.xlim(0, 100)
    plt.show()
    
bar_grouped_graph_display_df(all_years_combined_subject, all_years_combined_subject_br)

# %%
def bar_grouped_graph_display_df(df_ufpa, df_br, width=0.4):
    
    ax = plt.subplot(111)
    
    df_br = df_br.reindex_like(df_ufpa)
    if not df_ufpa.index.equals(df_br.index):
        raise ValueError("The indices of dataframes should be equal")
    
    
    ufpa_score_series = df_ufpa["Nota %"]
    br_score_series = df_br["Nota %"]
    
    merged_df = pd.DataFrame({"Nota % UFPA": ufpa_score_series,
                              "Nota % BR": br_score_series})
    
    merged_df["diff"] = merged_df["Nota % UFPA"] - merged_df["Nota % BR"]
    merged_df = merged_df.sort_values(by=["diff"])
    labels = merged_df.index

    ax.barh(labels, merged_df["diff"], color="black")

    
    ax.grid(axis = 'x', color ='white', linestyle='-')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.title("Differença no Percentual de Acerto Entre a Média da UFPA e a nacional")
    vals = ax.get_xticks()
    #ax.set_xticklabels([f'{int(x)} %' for x in vals])
    #plt.xlabel("%")
    #plt.xlim(0, 100)
    plt.show()
bar_grouped_graph_display_df(all_years_combined_subject, all_years_combined_subject_br)

# %%
def get_num_correct_poscomp_all_years(display_df: pd.DataFrame, subjects: list) -> int:
    result = 0
    for subject in subjects:
        if subject in display_df.index:
            result += display_df.loc[subject, "Acertos no Total (Acertos x Alunos)"]
    return result

def get_num_questions_poscomp_all_years(display_df: pd.DataFrame, subjects: list) -> int:
    result = 0
    for subject in subjects:
        if subject in display_df.index:
            result += display_df.loc[subject, "Questões Respondidas no total (Questões x Alunos)"]
    return result
    
def return_poscomp_score_all_years(display_df: pd.DataFrame):
    
    df = display_df.copy()
    
    # Add columns
    categories = [MATH_SUBJECTS, COMPUTING_SUBJECTS, TECHNOLOGY_SUBJECTS, HUMAN_SUBJECTS]
    labels = ["Matemática", "Fundamentos da Computação", "Tecnologias da Computação", 
              "Contexto Social e Profissional"]
    labels_with_questions = []
    for subjects, label in zip(categories, labels):
        
        # get score by student
        num_questions_subjects = get_num_questions_poscomp_all_years(display_df, subjects) 
        num_correct_subjects = get_num_correct_poscomp_all_years(display_df, subjects)
        score = (num_correct_subjects * 100) / num_questions_subjects
        
        new_dataframe = pd.DataFrame({"Questões Respondidas no total (Questões x Alunos)": num_questions_subjects,
                                      "Acertos no Total (Acertos x Alunos)": num_correct_subjects,
                                      "Nota %": score}, index=[label])
        df = df.append(new_dataframe)
        
    # return means core
    return df.loc[labels, "Nota %"]
poscomp_score_all_years = return_poscomp_score_all_years(all_years_combined_subject)
make_radar_plot(poscomp_score_all_years, "Percentual de Acerto por Área no ENADE considerando todos os anos")
poscomp_score_all_years
# Out:
# Matemática                        32.142857
# Fundamentos da Computação         34.177215
# Tecnologias da Computação         40.206186
# Contexto Social e Profissional    64.615385
# Name: Nota %, dtype: float64

# %%
def make_radar_plot_comparison(series_ufpa, series_br, title):
    fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
    colors = ['r', 'g']
    labels = ["UFPA", "BR"]
    for series, color, label in zip([series_ufpa, series_br], colors, labels):
        values = list(series.values)
        labels = list(series.index)


# Number of variables we're plotting.
        num_vars = len(labels)


# Split the circle into even parts and save the angles
# so we know where to put each axis.
        angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The plot is a circle, so we need to "complete the loop"
# and append the start value to the end.
        values += values[:1]
        angles += angles[:1]

# ax = plt.subplot(polar=True)
    

# Draw the outline of our data.
        ax.plot(angles, values, color=color, label=label)
# Fill it in.
        ax.fill(angles, values, facecolor=color, alpha=0.1)

# Fix axis to go in the right order and start at 12 o'clock.
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)

# Draw axis lines for each angle and label.

    ax.set_thetagrids(np.degrees(angles), labels)

# Go through labels and adjust alignment based on where
# it is in the circle.
    for label, angle in zip(ax.get_xticklabels(), angles):
        if angle in (0, np.pi):
            label.set_horizontalalignment('center')
        elif 0 < angle < np.pi:
            label.set_horizontalalignment('left')
        else:
            label.set_horizontalalignment('right')

# Ensure radar goes from 0 to 100.
    #ax.set_ylim(0, 100)
# You can also set gridlines manually like this:
# ax.set_rgrids([20, 40, 60, 80, 100])

# Set position of y-labels (0-100) to be in the middle
# of the first two axes.
    ax.set_rlabel_position(180 / num_vars)

# Add some custom styling.
# Change the color of the tick labels.
    ax.tick_params(colors='#222222')
# Make the y-axis (0-100) labels smaller.
    ax.tick_params(axis='y', labelsize=8)
# Change the color of the circular gridlines.
    ax.grid(color='#AAAAAA')
# Change the color of the outermost gridline (the spine).
    ax.spines['polar'].set_color('#222222')
# Change the background color inside the circle itself.
    ax.set_facecolor('#FAFAFA')
    #legend = ax.legend(["UFPA", "BR"], 
                       #labelspacing=0.1, fontsize='small')

# Lastly, give the chart a title and give it some
# padding above the "Acceleration" label.
    ax.set_title(title, y=1.08)
    plt.legend()
    plt.show()

# %%
poscomp_score_all_years_br = return_poscomp_score_all_years(all_years_combined_subject_br)
make_radar_plot_comparison(poscomp_score_all_years,
                           poscomp_score_all_years_br, 
                           "Percentual de Acerto por Área no ENADE considerando todos os anos")
poscomp_score_all_years_br
# Out:
# Matemática                        34.435474
# Fundamentos da Computação         31.388764
# Tecnologias da Computação         36.894791
# Contexto Social e Profissional    60.349443
# Name: Nota %, dtype: float64

# %%
def heatmap(data, row_labels, col_labels, ax=None,
            cbar_kw={}, cbarlabel="", **kwargs):
    """
    Create a heatmap from a numpy array and two lists of labels.

    Parameters
    ----------
    data
        A 2D numpy array of shape (N, M).
    row_labels
        A list or array of length N with the labels for the rows.
    col_labels
        A list or array of length M with the labels for the columns.
    ax
        A `matplotlib.axes.Axes` instance to which the heatmap is plotted.  If
        not provided, use current axes or create a new one.  Optional.
    cbar_kw
        A dictionary with arguments to `matplotlib.Figure.colorbar`.  Optional.
    cbarlabel
        The label for the colorbar.  Optional.
    **kwargs
        All other arguments are forwarded to `imshow`.
    """

    if not ax:
        ax = plt.gca(figsize=(220, 10))

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    
    cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
    current_cmap = matplotlib.cm.get_cmap()
    current_cmap.set_bad(color='red')
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=-30, ha="right",
             rotation_mode="anchor")

    # Turn spines off and create white grid.
    for edge, spine in ax.spines.items():
        spine.set_visible(False)

    ax.set_xticks(np.arange(data.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)

    return im, cbar


def annotate_heatmap(im, data=None, valfmt="{x:.2f}",
                     textcolors=["black", "white"],
                     threshold=None, **textkw):
    """
    A function to annotate a heatmap.

    Parameters
    ----------
    im
        The AxesImage to be labeled.
    data
        Data used to annotate.  If None, the image's data is used.  Optional.
    valfmt
        The format of the annotations inside the heatmap.  This should either
        use the string format method, e.g. "$ {x:.2f}", or be a
        `matplotlib.ticker.Formatter`.  Optional.
    textcolors
        A list or array of two color specifications.  The first is used for
        values below a threshold, the second for those above.  Optional.
    threshold
        Value in data units according to which the colors from textcolors are
        applied.  If None (the default) uses the middle of the colormap as
        separation.  Optional.
    **kwargs
        All other arguments are forwarded to each call to `text` used to create
        the text labels.
    """

    if not isinstance(data, (list, np.ndarray)):
        data = im.get_array()

    # Normalize the threshold to the images color range.
    if threshold is not None:
        threshold = im.norm(threshold)
    else:
        threshold = im.norm(data.max())/2.

    # Set default alignment to center, but allow it to be
    # overwritten by textkw.
    kw = dict(horizontalalignment="center",
              verticalalignment="center")
    kw.update(textkw)

    # Get the formatter in case a string is supplied
    if isinstance(valfmt, str):
        valfmt = matplotlib.ticker.StrMethodFormatter(valfmt)

    # Loop over the data and create a `Text` for each "pixel".
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            kw.update(color=textcolors[int(im.norm(data[i, j]) > threshold)])
            if str(data[i,j]) == "--":
                text = im.axes.text(j, i, "-", None, **kw)
            else:
                text = im.axes.text(j, i, valfmt(data[i, j], None), **kw)
            texts.append(text)

    return texts

# %%
plt.rcParams["figure.figsize"]=15, 15
fig, ax = plt.subplots()


df = display_all_years_nota(display_dfs)
df["Todos os Anos"] = get_all_years_combined_df(display_dfs, dfs, util.get_subjects(subject_df))["Nota %"]

#df = df.fillna("-")

im, cbar = heatmap(df.values, df.index, df.columns, ax=ax,
                   cmap="YlGn", cbarlabel="Percentual de Acerto")
texts = annotate_heatmap(im, valfmt="{x:.0f} %")
    
#fig.tight_layout()
#plt.figure(figsize=(20,5))
im.cmap.set_bad("gray")
plt.title(f"Desempenho ENADE por tema\n('Todos os anos'" 
          f"representa o desempenho geral considerando "
          f"todos os cinco exames realizados.\nOs campos "
          f"cinzas representam exames sem questões de determinado tema)")
plt.show()
plt.rcParams["figure.figsize"]=6,4
# Out:
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
num_questions_df = return_num_answered(display_dfs, dfs, False).sort_values()
ax = plt.subplot(111)
ax.barh(num_questions_df.index, num_questions_df.values, color="gray")
ax.grid(axis = 'x', color ='white', linestyle='-')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.title("Nº de questões por tema considerando os cinco exames realizados.")
plt.xlabel("Nº de Questões")
plt.show()

# %%
data = {"2005": display_dfs[2005]["Nº Questões"].copy(),
            "2008": display_dfs[2008]["Nº Questões"].copy(),
            "2011": display_dfs[2011]["Nº Questões"].copy(),
            "2014": display_dfs[2014]["Nº Questões"].copy(),
            "2017": display_dfs[2017]["Nº Questões"].copy()}
num_questions_by_year = pd.DataFrame(data)
#num_questions_by_year["Todos os Anos (Média)"] = num_questions_by_year.mean(axis=1)
num_questions_by_year
# Out:
#                                                     2005  2008  2011  2014  \
# Algoritmos e estruturas de dados                     3.0   2.0   5.0   2.0
# Arquitetura de computadores e sistemas operacio...   3.0   2.0   2.0   1.0
# Banco de dados                                       1.0   2.0   NaN   1.0
# Compiladores                                         1.0   3.0   2.0   2.0
# Computação gráfica e processamento de imagem         2.0   2.0   NaN   1.0
# Engenharia de software e interação homem-comput...   2.0   2.0   2.0   3.0
# Fundamentos e técnicas de programação                3.0   1.0   4.0   1.0
# Inteligência artificial e computacional              1.0   2.0   NaN   NaN
# Lógica e matemática discreta                         3.0   2.0   3.0   5.0
# Paradigmas de linguagens de programação              1.0   NaN   3.0   1.0
# Probabilidade e estatística                          NaN   2.0   1.0   NaN
# Redes de computadores                                2.0   5.0   2.0   NaN
# Sistemas digitais                                    1.0   2.0   1.0   1.0
# Sistemas distribuídos                                NaN   NaN   NaN   NaN
# Teoria da computação                                 2.0   2.0   3.0   3.0
# Teoria dos grafos                                    1.0   NaN   1.0   2.0
# Ética, computador e sociedade                        2.0   1.0   NaN   NaN
#
#                                                     2017
# Algoritmos e estruturas de dados                     4.0
# Arquitetura de computadores e sistemas operacio...   3.0
# Banco de dados                                       2.0
# Compiladores                                         1.0
# Computação gráfica e processamento de imagem         1.0
# Engenharia de software e interação homem-comput...   2.0
# Fundamentos e técnicas de programação                1.0
# Inteligência artificial e computacional              2.0
# Lógica e matemática discreta                         1.0
# Paradigmas de linguagens de programação              1.0
# Probabilidade e estatística                          NaN
# Redes de computadores                                2.0
# Sistemas digitais                                    1.0
# Sistemas distribuídos                                2.0
# Teoria da computação                                 2.0
# Teoria dos grafos                                    1.0
# Ética, computador e sociedade                        1.0

# %%
plt.rcParams["figure.figsize"]=15, 15
fig, ax = plt.subplots()
num_questions_by_year = num_questions_by_year.fillna(0)
im, cbar = heatmap(num_questions_by_year.values, num_questions_by_year.index, num_questions_by_year.columns, ax=ax,
                   cmap="YlGn", cbarlabel="Nº de Questões")
texts = annotate_heatmap(im, valfmt="{x:.0f}")
    
#fig.tight_layout()
#plt.figure(figsize=(20,5))
im.cmap.set_bad("gray")
plt.title(f"Nº de Questões no ENADE por tema")
plt.show()
plt.rcParams["figure.figsize"]=6,4
